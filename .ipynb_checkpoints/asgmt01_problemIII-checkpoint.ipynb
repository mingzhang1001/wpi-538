# %%
import numpy as np
from sklearn.decomposition import PCA
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
import seaborn as sns
# %matplotlib inline
# Loading data
data = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data",
                   delim_whitespace = True, header=None,
                   names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration',

                            'model', 'origin', 'car_name'])
data = data.drop(columns='car_name')
df_num = data[data['horsepower'] != '?'].astype(float)

# standardize the data 
df_stdrd = (df_num-df_num.mean())/df_num.std()
df_stdrd.head()
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0 -0.697747   1.482053      1.075915    0.663285  0.619748     -1.283618
# 1 -1.082115   1.482053      1.486832    1.572585  0.842258     -1.464852
# 2 -0.697747   1.482053      1.181033    1.182885  0.539692     -1.646086
# 3 -0.953992   1.482053      1.047246    1.182885  0.536160     -1.283618
# 4 -0.825870   1.482053      1.028134    0.923085  0.554997     -1.827320
#
#       model    origin
# 0 -1.623241 -0.715726
# 1 -1.623241 -0.715726
# 2 -1.623241 -0.715726
# 3 -1.623241 -0.715726
# 4 -1.623241 -0.715726

# %%
# standardize the data
l_stdrd = scale(df_num.values)
df_stdrd = pd.DataFrame(l_stdrd, columns = df_stdrd.columns)
df_stdrd.head()
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0 -0.698638   1.483947      1.077290    0.664133  0.620540     -1.285258
# 1 -1.083498   1.483947      1.488732    1.574594  0.843334     -1.466724
# 2 -0.698638   1.483947      1.182542    1.184397  0.540382     -1.648189
# 3 -0.955212   1.483947      1.048584    1.184397  0.536845     -1.285258
# 4 -0.826925   1.483947      1.029447    0.924265  0.555706     -1.829655
#
#       model    origin
# 0 -1.625315 -0.716641
# 1 -1.625315 -0.716641
# 2 -1.625315 -0.716641
# 3 -1.625315 -0.716641
# 4 -1.625315 -0.716641

# %%
#run PCA on standardized data
pca = PCA(n_components=8)
X = pca.fit_transform(df_stdrd)
X_pca = pca.transform(X)

# set up a list to index components starting with #1 instead of zero
pc_nums = list(range(1, X_pca.shape[1]+1))
# save component data as a dataframe.  Use new index array for indexing df
comp_df = pd.DataFrame(pca.components_, columns=df_stdrd.columns, index=pc_nums)

# add column with total explained variance for each component
comp_df["VARIANCE"] = pca.explained_variance_ratio_

#display dataframe with rounded values
round(abs(comp_df),2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 1  0.39       0.40          0.42        0.40    0.40          0.26   0.21
# 2  0.08       0.14          0.13        0.11    0.21          0.42   0.69
# 3  0.29       0.07          0.07        0.24    0.00          0.64   0.59
# 4  0.10       0.22          0.14        0.12    0.32          0.49   0.11
# 5  0.74       0.48          0.30        0.08    0.13          0.10   0.30
# 6  0.39       0.53          0.01        0.67    0.24          0.20   0.11
# 7  0.20       0.28          0.08        0.54    0.72          0.23   0.13
# 8  0.12       0.42          0.83        0.13    0.31          0.04   0.05
#
#    origin  VARIANCE
# 1    0.28      0.67
# 2    0.50      0.12
# 3    0.31      0.10
# 4    0.74      0.06
# 5    0.05      0.02
# 6    0.12      0.01
# 7    0.03      0.01
# 8    0.08      0.00

# %%
df_pca = pd.DataFrame({'Variance':comp_df["VARIANCE"],
             'Principle Components':['PC1','PC2','PC3','PC4', 'PC5','PC6', 'PC7', 'PC8']})
sns.barplot(x='Principle Components',y="Variance", 
            data=df_pca, color="c");
plt.plot(comp_df["VARIANCE"])
comp_df["VARIANCE"]
# Out:
# 1    0.671984
# 2    0.117958
# 3    0.101455
# 4    0.060769
# 5    0.022853
# 6    0.014290
# 7    0.006693
# 8    0.003996
# Name: VARIANCE, dtype: float64
